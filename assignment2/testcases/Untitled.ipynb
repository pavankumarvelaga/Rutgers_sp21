# %%
import pickle
import os

# %%
# !pwd
# Out:
# /Users/pavankumar/Rutgers/Spring21/Assignments/cs520/assignment2/testcases

# %%
import pandas as pd
dict_ = {}
for i in os.listdir("./"):
    if len(i.split(".")) != 2:
        dict_[i] = pd.read_pickle(i)

# %%
dict_
# Out:
# {'graph_1': ({1: [1,
#     False,
#     0,
#     0,
#     4.5,
#     [(2, 10), (3, 5), (4, 8), (5, 11)],
#     {2: 10, 3: 5, 4: 8, 5: 11}],
#    2: [2, False, 0, 0, 1.0, [(1, 10), (4, 1)], {1: 10, 4: 1}],
#    3: [3, False, 0, 0, 3.0, [(1, 5), (4, 9), (5, 6)], {1: 5, 4: 9, 5: 6}],
#    4: [4,
#     False,
#     0,
#     0,
#     0.5,
#     [(1, 8), (2, 1), (3, 9), (5, 1)],
#     {1: 8, 2: 1, 3: 9, 5: 1}],
#    5: [5, False, 0, 0, 0.0, [(1, 11), (3, 6), (4, 1)], {1: 11, 3: 6, 4: 1}]},
#   1,
#   5,
#   (2, 11, [1, 5]),
#   (5, 11, [1, 5]),
#   (5, 9, [1, 4, 5]),
#   (4, 9, [1, 4, 5])),
#  'state_3': ([10, 9, 3, 8, 7, 2, 4, 1, 6, 5], 6.0, False),
#  'state_4': ([11, 8, 10, 9, 3, 1, 4, 6, 12, 2, 5, 7], 4.0, True),
#  'state_5': ([14, 5, 9, 2, 4, 3, 13, 12, 6, 1, 7, 11, 10, 8], 9.0, False),
#  'state_2': ([3, 2, 6, 5, 4, 7, 1, 8], 6.0, False),
#  'graph_4': ({1: [1,
#     False,
#     0,
#     0,
#     23.0,
#     [(7, 42),
#      (10, 50),
#      (11, 13),
#      (12, 45),
# ...
